# %%
# !apt -yq install swig >/dev/null
# !pip -q install "gymnasium[box2d]" imageio imageio-ffmpeg opencv-python-headless einops
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#   Preparing metadata (setup.py) ... done
#   Building wheel for box2d-py (setup.py) ... done

# %%
pip install "gymnasium[box2d]" torch numpy imageio imageio-ffmpeg opencv-python-headless
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (2.37.0)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.12/dist-packages (from imageio) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Using cached swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
# Building wheels for collected packages: box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (box2d-py)

# %%
# === SAC on LunarLanderContinuous-v2 + MP4 recording ===
# Colab tip (one-time): !pip -q install "gymnasium[box2d]" torch numpy imageio imageio-ffmpeg opencv-python-headless

import os, math, random, time
from dataclasses import dataclass
from typing import Tuple
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

import gymnasium as gym
from gymnasium.wrappers import RecordVideo

# ------------- Utils -------------
def set_seed(seed: int):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)

def to_tensor(x, device): return torch.as_tensor(x, dtype=torch.float32, device=device)

def mlp(sizes, activation=nn.ReLU, output_activation=nn.Identity):
    layers = []
    for j in range(len(sizes)-1):
        act = activation if j < len(sizes)-2 else output_activation
        layers += [nn.Linear(sizes[j], sizes[j+1]), act()]
    return nn.Sequential(*layers)

# ------------- Replay -------------
class ReplayBuffer:
    def __init__(self, obs_dim, act_dim, size, device):
        self.obs = np.zeros((size, obs_dim), np.float32)
        self.obs2 = np.zeros((size, obs_dim), np.float32)
        self.acts = np.zeros((size, act_dim), np.float32)
        self.rews = np.zeros(size, np.float32)
        self.done = np.zeros(size, np.float32)
        self.ptr = 0; self.size = 0; self.max_size = size; self.device = device
    def store(self, o, a, r, o2, d):
        i = self.ptr
        self.obs[i], self.acts[i], self.rews[i], self.obs2[i], self.done[i] = o, a, r, o2, d
        self.ptr = (self.ptr + 1) % self.max_size
        self.size = min(self.size + 1, self.max_size)
    def sample(self, batch_size):
        idx = np.random.randint(0, self.size, size=batch_size)
        return dict(
            obs=to_tensor(self.obs[idx], self.device),
            obs2=to_tensor(self.obs2[idx], self.device),
            acts=to_tensor(self.acts[idx], self.device),
            rews=to_tensor(self.rews[idx], self.device).unsqueeze(-1),
            done=to_tensor(self.done[idx], self.device).unsqueeze(-1),
        )

# ------------- Networks -------------
class SquashedGaussianActor(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden=(256,256), log_std_bounds=(-20,2), action_low=None, action_high=None):
        super().__init__()
        self.net = mlp([obs_dim, *hidden], nn.ReLU, nn.ReLU)
        self.mu = nn.Linear(hidden[-1], act_dim)
        self.log_std = nn.Linear(hidden[-1], act_dim)
        self.lmin, self.lmax = log_std_bounds
        self.register_buffer('a_low', torch.as_tensor(action_low, dtype=torch.float32))
        self.register_buffer('a_high', torch.as_tensor(action_high, dtype=torch.float32))
        self.register_buffer('a_scale', (self.a_high - self.a_low)/2.0)
        self.register_buffer('a_mean',  (self.a_high + self.a_low)/2.0)
    def forward(self, o):
        h = self.net(o)
        mu = self.mu(h)
        log_std = torch.clamp(self.log_std(h), self.lmin, self.lmax)
        std = torch.exp(log_std)
        return mu, std
    @torch.no_grad()
    def act_mean(self, o):
        mu, _ = self.forward(o); y = torch.tanh(mu)
        return self.a_mean + self.a_scale * y
    def sample(self, o):
        mu, std = self.forward(o)
        dist = torch.distributions.Normal(mu, std)
        u = dist.rsample()               # pre-tanh
        y = torch.tanh(u)                # [-1,1]
        a = self.a_mean + self.a_scale * y
        logp = dist.log_prob(u).sum(-1, keepdim=True)
        logp -= torch.log(1 - y.pow(2) + 1e-6).sum(-1, keepdim=True)
        logp -= torch.log(self.a_scale).sum().view(1,1)
        return a, logp

class QCritic(nn.Module):
    def __init__(self, obs_dim, act_dim, hidden=(256,256)):
        super().__init__()
        self.q = mlp([obs_dim+act_dim, *hidden, 1], nn.ReLU, nn.Identity)
    def forward(self, o, a): return self.q(torch.cat([o,a], dim=-1))

# ------------- SAC Core -------------
@dataclass
class SACConfig:
    env_id: str = "LunarLanderContinuous-v3"
    seed: int = 0
    steps: int = 200_000
    start_steps: int = 5_000
    update_after: int = 5_000
    update_every: int = 1
    batch_size: int = 256
    gamma: float = 0.99
    tau: float = 0.005
    actor_lr: float = 3e-4
    critic_lr: float = 3e-4
    alpha_lr: float = 3e-4
    hidden: Tuple[int,int] = (256,256)
    target_entropy_scale: float = 1.0
    eval_episodes: int = 5
    video_folder: str = "videos"
    video_name: str = "sac_lander_demo"

class SACAgent:
    def __init__(self, obs_space, act_space, cfg: SACConfig, device):
        obs_dim = int(np.prod(obs_space.shape))
        act_dim = int(np.prod(act_space.shape))
        self.cfg, self.device = cfg, device
        a_low, a_high = np.asarray(act_space.low, np.float32), np.asarray(act_space.high, np.float32)
        self.actor = SquashedGaussianActor(obs_dim, act_dim, cfg.hidden, action_low=a_low, action_high=a_high).to(device)
        self.q1 = QCritic(obs_dim, act_dim, cfg.hidden).to(device)
        self.q2 = QCritic(obs_dim, act_dim, cfg.hidden).to(device)
        self.q1_t = QCritic(obs_dim, act_dim, cfg.hidden).to(device)
        self.q2_t = QCritic(obs_dim, act_dim, cfg.hidden).to(device)
        self.q1_t.load_state_dict(self.q1.state_dict())
        self.q2_t.load_state_dict(self.q2.state_dict())
        self.pi_opt  = torch.optim.Adam(self.actor.parameters(), lr=cfg.actor_lr)
        self.q1_opt  = torch.optim.Adam(self.q1.parameters(),   lr=cfg.critic_lr)
        self.q2_opt  = torch.optim.Adam(self.q2.parameters(),   lr=cfg.critic_lr)
        self.log_alpha = torch.tensor(0.0, requires_grad=True, device=device)
        self.a_opt = torch.optim.Adam([self.log_alpha], lr=cfg.alpha_lr)
        self.target_entropy = - cfg.target_entropy_scale * act_dim
    @property
    def alpha(self): return self.log_alpha.exp()
    def select(self, o, deterministic=False):
        o = to_tensor(o, self.device).unsqueeze(0)
        with torch.no_grad():
            if deterministic: a = self.actor.act_mean(o)
            else: a, _ = self.actor.sample(o)
        return a.cpu().numpy()[0]
    def update(self, batch):
        o, o2, a, r, d = batch['obs'], batch['obs2'], batch['acts'], batch['rews'], batch['done']
        with torch.no_grad():
            a2, logp2 = self.actor.sample(o2)
            q1_t = self.q1_t(o2, a2); q2_t = self.q2_t(o2, a2)
            q_targ = torch.min(q1_t, q2_t) - self.alpha * logp2
            backup = r + self.cfg.gamma * (1 - d) * q_targ
        q1 = self.q1(o, a); q2 = self.q2(o, a)
        lq1 = F.mse_loss(q1, backup); lq2 = F.mse_loss(q2, backup)
        self.q1_opt.zero_grad(set_to_none=True); lq1.backward(); self.q1_opt.step()
        self.q2_opt.zero_grad(set_to_none=True); lq2.backward(); self.q2_opt.step()
        api, logpi = self.actor.sample(o)
        qpi = torch.min(self.q1(o, api), self.q2(o, api))
        lpi = (self.alpha * logpi - qpi).mean()
        self.pi_opt.zero_grad(set_to_none=True); lpi.backward(); self.pi_opt.step()
        lalpha = -(self.log_alpha * (logpi.detach() + self.target_entropy)).mean()
        self.a_opt.zero_grad(set_to_none=True); lalpha.backward(); self.a_opt.step()
        with torch.no_grad():
            for p, pt in zip(self.q1.parameters(), self.q1_t.parameters()):
                pt.data.mul_(1 - self.cfg.tau); pt.data.add_(self.cfg.tau * p.data)
            for p, pt in zip(self.q2.parameters(), self.q2_t.parameters()):
                pt.data.mul_(1 - self.cfg.tau); pt.data.add_(self.cfg.tau * p.data)
        return dict(lq1=lq1.item(), lq2=lq2.item(), lpi=lpi.item(), alpha=self.alpha.item())

# ------------- Eval & Record -------------
def eval_policy(env_fn, agent, episodes=5, seed=None):
    env = env_fn()
    if seed is not None: env.reset(seed=seed)
    rets = []
    for _ in range(episodes):
        o, _ = env.reset()
        done, ep_ret = False, 0.0
        while not done:
            o, r, term, trunc, _ = env.step(agent.select(o, deterministic=True))
            ep_ret += float(r); done = term or trunc
        rets.append(ep_ret)
    env.close()
    return float(np.mean(rets)), float(np.std(rets))

def record_one_episode(agent, cfg: SACConfig, out_folder="videos", name_prefix="sac_lander_demo"):
    os.makedirs(out_folder, exist_ok=True)
    # render_mode must be rgb_array for RecordVideo
    env = gym.make(cfg.env_id, render_mode="rgb_array")
    env = RecordVideo(env, video_folder=out_folder, name_prefix=name_prefix, episode_trigger=lambda ep: True)
    o, _ = env.reset()
    done = False
    while not done:
        a = agent.select(o, deterministic=True)
        o, r, term, trunc, _ = env.step(a)
        done = term or trunc
    env.close()
    return out_folder  # mp4 is saved automatically

# ------------- Train + Record -------------
def train_and_record():
    cfg = SACConfig()
    set_seed(cfg.seed)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def make_env(): return gym.make(cfg.env_id)
    env = make_env()
    obs_space, act_space = env.observation_space, env.action_space
    assert len(act_space.shape) == 1, "Continuous Box action space required."

    agent = SACAgent(obs_space, act_space, cfg, device)
    buf = ReplayBuffer(obs_space.shape[0], act_space.shape[0], size=300_000, device=device)

    o, _ = env.reset(seed=cfg.seed)
    ep_ret, ep_len = 0.0, 0
    print(f"Device: {device} | Env: {cfg.env_id} | Obs: {obs_space.shape} | Act: {act_space.shape}")

    for t in range(1, cfg.steps + 1):
        a = act_space.sample() if t < cfg.start_steps else agent.select(o)
        o2, r, term, trunc, _ = env.step(a)
        d = float(term or trunc)
        buf.store(o, a, r, o2, d)
        o = o2; ep_ret += float(r); ep_len += 1
        if d:
            print(f"[Step {t:>7}] EpRet: {ep_ret:7.1f} | EpLen: {ep_len:4d}")
            o, _ = env.reset(); ep_ret, ep_len = 0.0, 0

        if t >= cfg.update_after and t % cfg.update_every == 0:
            info = agent.update(buf.sample(cfg.batch_size))
            if t % 2000 == 0:
                print(f"[Upd {t:>7}] alpha={info['alpha']:.3f} | Lq1={info['lq1']:.3f} | Lq2={info['lq2']:.3f} | Lpi={info['lpi']:.3f}")

        if t % 10_000 == 0:
            mean_ret, std_ret = eval_policy(make_env, agent, episodes=cfg.eval_episodes)
            print(f"== Eval @ {t:>7} steps: mean={mean_ret:.1f} ± {std_ret:.1f}")

    env.close()
    print("Training done. Recording deterministic demo...")
    folder = record_one_episode(agent, cfg, out_folder=cfg.video_folder, name_prefix=cfg.video_name)
    print(f"Saved video(s) to: {os.path.abspath(folder)}")
train_and_record()
# Out:
# Device: cpu | Env: LunarLanderContinuous-v3 | Obs: (8,) | Act: (2,)
# [Step      80] EpRet:    74.9 | EpLen:   80
# [Step     207] EpRet:  -302.5 | EpLen:  127
# [Step     315] EpRet:  -309.4 | EpLen:  108
# [Step     413] EpRet:  -403.5 | EpLen:   98
# [Step     513] EpRet:  -250.8 | EpLen:  100
# [Step     686] EpRet:  -294.8 | EpLen:  173
# [Step     814] EpRet:   -21.9 | EpLen:  128
# [Step     980] EpRet:   -65.5 | EpLen:  166
# [Step    1064] EpRet:  -195.7 | EpLen:   84
# [Step    1189] EpRet:   -61.2 | EpLen:  125
# [Step    1283] EpRet:  -167.3 | EpLen:   94
# [Step    1418] EpRet:  -135.4 | EpLen:  135
# [Step    1518] EpRet:   -46.0 | EpLen:  100
# [Step    2518] EpRet:    14.6 | EpLen: 1000
# [Step    2640] EpRet:  -155.2 | EpLen:  122
# [Step    2785] EpRet:  -199.2 | EpLen:  145
# [Step    2918] EpRet:  -373.3 | EpLen:  133
# [Step    3005] EpRet:   -70.4 | EpLen:   87
# [Step    3085] EpRet:  -206.4 | EpLen:   80
# [Step    3188] EpRet:   -64.1 | EpLen:  103
# [Step    3349] EpRet:  -106.4 | EpLen:  161
# [Step    3437] EpRet:   -50.4 | EpLen:   88
# [Step    3524] EpRet:  -161.8 | EpLen:   87
# [Step    3695] EpRet:  -111.6 | EpLen:  171
# [Step    3843] EpRet:  -244.4 | EpLen:  148
# [Step    3964] EpRet:   -47.4 | EpLen:  121
# [Step    4033] EpRet:  -186.0 | EpLen:   69
# [Step    4157] EpRet:  -210.8 | EpLen:  124
# [Step    4331] EpRet:   -68.3 | EpLen:  174
# [Step    4429] EpRet:   -85.9 | EpLen:   98
# [Step    4517] EpRet:  -373.8 | EpLen:   88
# [Step    4599] EpRet:  -112.0 | EpLen:   82
# [Step    4730] EpRet:  -154.7 | EpLen:  131
# [Step    4929] EpRet:  -424.9 | EpLen:  199
# [Step    5031] EpRet:  -223.0 | EpLen:  102
# [Step    5244] EpRet:  -178.8 | EpLen:  213
# [Step    5430] EpRet:    -0.8 | EpLen:  186
# [Step    5540] EpRet:  -312.5 | EpLen:  110
# [Step    5667] EpRet:  -277.5 | EpLen:  127
# [Step    5774] EpRet:  -267.9 | EpLen:  107
# [Step    5933] EpRet:  -303.9 | EpLen:  159
# [Upd    6000] alpha=0.750 | Lq1=35.506 | Lq2=34.969 | Lpi=-1.727
# [Step    6052] EpRet:  -214.3 | EpLen:  119
# [Step    6225] EpRet:  -353.6 | EpLen:  173
# [Step    6379] EpRet:  -238.6 | EpLen:  154
# [Step    6558] EpRet:  -207.8 | EpLen:  179
# [Step    6929] EpRet:  -101.5 | EpLen:  371
# [Step    7203] EpRet:  -517.6 | EpLen:  274
# [Step    7480] EpRet:  -280.1 | EpLen:  277
# [Step    7953] EpRet:   -14.7 | EpLen:  473
# [Upd    8000] alpha=0.440 | Lq1=18.674 | Lq2=19.890 | Lpi=-3.797
# [Step    8953] EpRet:   111.6 | EpLen: 1000
# [Step    9533] EpRet:  -212.0 | EpLen:  580
# [Step    9980] EpRet:  -118.6 | EpLen:  447
# [Upd   10000] alpha=0.277 | Lq1=6.478 | Lq2=5.478 | Lpi=-5.108
# == Eval @   10000 steps: mean=-66.7 ± 24.9
# [Step   10886] EpRet:  -375.5 | EpLen:  906
# [Step   11121] EpRet:   -58.3 | EpLen:  235
# [Step   11398] EpRet:   -49.1 | EpLen:  277
# [Step   11626] EpRet:    24.8 | EpLen:  228
# [Upd   12000] alpha=0.186 | Lq1=33.018 | Lq2=32.942 | Lpi=-9.508
# [Step   12626] EpRet:   -88.7 | EpLen: 1000
# [Step   12753] EpRet:  -117.0 | EpLen:  127
# [Step   13268] EpRet:  -225.8 | EpLen:  515
# [Step   13846] EpRet:  -259.2 | EpLen:  578
# [Upd   14000] alpha=0.145 | Lq1=50.993 | Lq2=48.634 | Lpi=-15.901
# [Step   14289] EpRet:  -287.7 | EpLen:  443
# [Step   14718] EpRet:  -155.6 | EpLen:  429
# [Step   15076] EpRet:  -207.7 | EpLen:  358
# [Step   15433] EpRet:   -96.2 | EpLen:  357
# [Step   15890] EpRet:  -136.7 | EpLen:  457
# [Upd   16000] alpha=0.130 | Lq1=15.966 | Lq2=17.617 | Lpi=-19.772
# [Step   16116] EpRet:   -97.1 | EpLen:  226
# [Step   16868] EpRet:  -199.9 | EpLen:  752
# [Step   17451] EpRet:  -235.9 | EpLen:  583
# [Step   17800] EpRet:  -212.6 | EpLen:  349
# [Upd   18000] alpha=0.136 | Lq1=19.953 | Lq2=23.725 | Lpi=-23.494
# [Step   18032] EpRet:   -52.8 | EpLen:  232
# [Step   19032] EpRet:   -51.9 | EpLen: 1000
# [Step   19283] EpRet:  -101.0 | EpLen:  251
# [Step   19675] EpRet:  -499.6 | EpLen:  392
# [Step   19894] EpRet:   -93.9 | EpLen:  219
# [Upd   20000] alpha=0.129 | Lq1=72.346 | Lq2=59.791 | Lpi=-21.812
# == Eval @   20000 steps: mean=-110.0 ± 72.7
# [Step   20189] EpRet:   -28.7 | EpLen:  295
# [Step   20592] EpRet:  -163.6 | EpLen:  403
# [Step   20851] EpRet:   -59.7 | EpLen:  259
# [Step   21110] EpRet:  -172.3 | EpLen:  259
# [Step   21367] EpRet:  -254.1 | EpLen:  257
# [Step   21926] EpRet:  -265.6 | EpLen:  559
# [Upd   22000] alpha=0.125 | Lq1=10.058 | Lq2=10.378 | Lpi=-22.169
# [Step   22189] EpRet:  -288.9 | EpLen:  263
# [Step   22719] EpRet:  -444.7 | EpLen:  530
# [Step   23719] EpRet:   -53.9 | EpLen: 1000
# [Step   23963] EpRet:  -247.8 | EpLen:  244
# [Upd   24000] alpha=0.120 | Lq1=85.829 | Lq2=72.940 | Lpi=-20.224
# [Step   24637] EpRet:  -301.3 | EpLen:  674
# [Step   24708] EpRet:   -54.2 | EpLen:   71
# [Step   25526] EpRet:  -177.2 | EpLen:  818
# [Upd   26000] alpha=0.139 | Lq1=90.736 | Lq2=97.144 | Lpi=-20.570
# [Step   26526] EpRet:    42.4 | EpLen: 1000
# [Step   26614] EpRet:   -98.7 | EpLen:   88
# [Step   26680] EpRet:     9.0 | EpLen:   66
# [Step   27680] EpRet:    71.9 | EpLen: 1000
# [Step   27739] EpRet:   -64.2 | EpLen:   59
# [Step   27865] EpRet:    33.5 | EpLen:  126
# [Step   27964] EpRet:    -8.2 | EpLen:   99
# [Upd   28000] alpha=0.151 | Lq1=24.100 | Lq2=27.448 | Lpi=-22.731
# [Step   28026] EpRet:   -61.1 | EpLen:   62
# [Step   28092] EpRet:   -73.0 | EpLen:   66
# [Step   28170] EpRet:    39.2 | EpLen:   78
# [Step   28234] EpRet:   -24.1 | EpLen:   64
# [Step   28336] EpRet:    -7.0 | EpLen:  102
# [Step   28469] EpRet:    24.1 | EpLen:  133
# [Step   28556] EpRet:   -44.1 | EpLen:   87
# [Step   28615] EpRet:   -61.2 | EpLen:   59
# [Step   28680] EpRet:   -48.6 | EpLen:   65
# [Step   29680] EpRet:    49.5 | EpLen: 1000
# [Step   29765] EpRet:   -41.8 | EpLen:   85
# [Upd   30000] alpha=0.141 | Lq1=14.482 | Lq2=14.260 | Lpi=-24.468
# == Eval @   30000 steps: mean=-34.5 ± 84.9
# [Step   30348] EpRet:   -81.7 | EpLen:  583
# [Step   31348] EpRet:   -18.0 | EpLen: 1000
# [Step   31457] EpRet:    19.8 | EpLen:  109
# [Upd   32000] alpha=0.125 | Lq1=56.822 | Lq2=55.666 | Lpi=-24.950
# [Step   32457] EpRet:    25.5 | EpLen: 1000
# [Step   32577] EpRet:   -65.3 | EpLen:  120
# [Step   33297] EpRet:   167.3 | EpLen:  720
# [Step   33422] EpRet:   -64.6 | EpLen:  125
# [Step   33504] EpRet:   -59.9 | EpLen:   82
# [Upd   34000] alpha=0.155 | Lq1=12.325 | Lq2=13.619 | Lpi=-27.293
# [Step   34504] EpRet:    46.4 | EpLen: 1000
# [Step   35439] EpRet:   155.7 | EpLen:  935
# [Upd   36000] alpha=0.148 | Lq1=8.661 | Lq2=11.050 | Lpi=-24.977
# [Step   36439] EpRet:    21.0 | EpLen: 1000
# [Step   36530] EpRet:   -27.3 | EpLen:   91
# [Step   36822] EpRet:  -209.7 | EpLen:  292
# [Step   36958] EpRet:   -54.8 | EpLen:  136
# [Step   37686] EpRet:   219.9 | EpLen:  728
# [Upd   38000] alpha=0.140 | Lq1=23.336 | Lq2=25.315 | Lpi=-24.896
# [Step   38686] EpRet:    81.0 | EpLen: 1000
# [Step   39192] EpRet:   218.3 | EpLen:  506
# [Step   39639] EpRet:   212.8 | EpLen:  447
# [Upd   40000] alpha=0.146 | Lq1=7.168 | Lq2=8.623 | Lpi=-20.989
# == Eval @   40000 steps: mean=175.0 ± 83.2
# [Step   40577] EpRet:   215.9 | EpLen:  938
# [Step   40946] EpRet:   252.7 | EpLen:  369
# [Step   41109] EpRet:  -233.5 | EpLen:  163
# [Step   41628] EpRet:   148.0 | EpLen:  519
# [Step   41999] EpRet:   276.5 | EpLen:  371
# [Upd   42000] alpha=0.142 | Lq1=8.320 | Lq2=9.582 | Lpi=-28.655
# [Step   42664] EpRet:   207.9 | EpLen:  665
# [Step   42974] EpRet:   243.3 | EpLen:  310
# [Step   43508] EpRet:  -299.4 | EpLen:  534
# [Step   43801] EpRet:   296.1 | EpLen:  293
# [Upd   44000] alpha=0.153 | Lq1=33.348 | Lq2=34.823 | Lpi=-27.524
# [Step   44089] EpRet:   254.5 | EpLen:  288
# [Step   44305] EpRet:    30.0 | EpLen:  216
# [Step   44589] EpRet:   284.1 | EpLen:  284
# [Step   44850] EpRet:   287.3 | EpLen:  261
# [Step   45373] EpRet:   228.6 | EpLen:  523
# [Step   45918] EpRet:  -131.1 | EpLen:  545
# [Upd   46000] alpha=0.171 | Lq1=16.726 | Lq2=21.074 | Lpi=-27.502
# [Step   46500] EpRet:  -446.7 | EpLen:  582
# [Step   46633] EpRet:    29.5 | EpLen:  133
# [Step   46915] EpRet:   250.4 | EpLen:  282
# [Step   47212] EpRet:   247.0 | EpLen:  297
# [Upd   48000] alpha=0.159 | Lq1=8.151 | Lq2=7.850 | Lpi=-29.850
# [Step   48212] EpRet:    -3.6 | EpLen: 1000
# [Step   48303] EpRet:   -60.6 | EpLen:   91
# [Step   49303] EpRet:     0.1 | EpLen: 1000
# [Step   49597] EpRet:   253.2 | EpLen:  294
# [Step   49712] EpRet:   -46.4 | EpLen:  115
# [Step   49812] EpRet:   -45.2 | EpLen:  100
# [Upd   50000] alpha=0.164 | Lq1=6.247 | Lq2=6.253 | Lpi=-26.909
# == Eval @   50000 steps: mean=47.1 ± 169.0
# [Step   50123] EpRet:   278.2 | EpLen:  311
# [Step   50258] EpRet:    22.8 | EpLen:  135
# [Step   50993] EpRet:   255.1 | EpLen:  735
# [Step   51921] EpRet:    81.4 | EpLen:  928
# [Upd   52000] alpha=0.153 | Lq1=23.918 | Lq2=25.463 | Lpi=-33.553
# [Step   52085] EpRet:    -5.0 | EpLen:  164
# [Step   53085] EpRet:   104.4 | EpLen: 1000
# [Step   53890] EpRet:   173.6 | EpLen:  805
# [Upd   54000] alpha=0.150 | Lq1=23.607 | Lq2=20.848 | Lpi=-34.016
# [Step   54835] EpRet:   205.4 | EpLen:  945
# [Step   55091] EpRet:  -110.2 | EpLen:  256
# [Step   55499] EpRet:   254.0 | EpLen:  408
# [Upd   56000] alpha=0.139 | Lq1=10.976 | Lq2=11.378 | Lpi=-31.573
# [Step   56099] EpRet:   162.5 | EpLen:  600
# [Step   57099] EpRet:   -17.5 | EpLen: 1000
# [Upd   58000] alpha=0.134 | Lq1=13.053 | Lq2=11.731 | Lpi=-34.633
# [Step   58099] EpRet:    15.9 | EpLen: 1000
# [Step   58659] EpRet:   213.7 | EpLen:  560
# [Step   59356] EpRet:   255.6 | EpLen:  697
# [Step   59833] EpRet:   199.0 | EpLen:  477
# [Upd   60000] alpha=0.132 | Lq1=28.123 | Lq2=29.454 | Lpi=-38.589
# == Eval @   60000 steps: mean=126.5 ± 148.2
# [Step   60434] EpRet:   206.2 | EpLen:  601
# [Step   60715] EpRet:   232.2 | EpLen:  281
# [Step   61558] EpRet:   168.2 | EpLen:  843
# [Upd   62000] alpha=0.123 | Lq1=33.007 | Lq2=30.793 | Lpi=-34.098
# [Step   62051] EpRet:   249.1 | EpLen:  493
# [Step   62431] EpRet:   -15.3 | EpLen:  380
# [Step   63018] EpRet:   222.7 | EpLen:  587
# [Step   63571] EpRet:   232.4 | EpLen:  553
# [Step   63943] EpRet:   215.0 | EpLen:  372
# [Upd   64000] alpha=0.122 | Lq1=22.778 | Lq2=29.044 | Lpi=-31.818
# [Step   64303] EpRet:   221.5 | EpLen:  360
# [Step   64813] EpRet:   253.2 | EpLen:  510
# [Step   65315] EpRet:   199.6 | EpLen:  502
# [Step   65929] EpRet:   132.4 | EpLen:  614
# [Upd   66000] alpha=0.115 | Lq1=18.739 | Lq2=19.177 | Lpi=-34.058
# [Step   66465] EpRet:   249.7 | EpLen:  536
# [Step   66990] EpRet:   218.0 | EpLen:  525
# [Step   67426] EpRet:   249.8 | EpLen:  436
# [Step   67781] EpRet:   243.7 | EpLen:  355
# [Upd   68000] alpha=0.115 | Lq1=10.282 | Lq2=8.104 | Lpi=-32.587
# [Step   68126] EpRet:   254.0 | EpLen:  345
# [Step   68629] EpRet:   240.9 | EpLen:  503
# [Step   69038] EpRet:  -212.1 | EpLen:  409
# [Step   69456] EpRet:   233.0 | EpLen:  418
# [Step   69754] EpRet:   253.3 | EpLen:  298
# [Step   69968] EpRet:  -152.8 | EpLen:  214
# [Upd   70000] alpha=0.113 | Lq1=10.723 | Lq2=9.839 | Lpi=-33.464
# == Eval @   70000 steps: mean=207.4 ± 28.6
# [Step   70078] EpRet:     7.9 | EpLen:  110
# [Step   70663] EpRet:   -28.4 | EpLen:  585
# [Step   70760] EpRet:   -40.4 | EpLen:   97
# [Step   71251] EpRet:   207.2 | EpLen:  491
# [Step   71429] EpRet:   281.3 | EpLen:  178
# [Step   71812] EpRet:   257.3 | EpLen:  383
# [Upd   72000] alpha=0.112 | Lq1=6.159 | Lq2=5.801 | Lpi=-33.106
# [Step   72210] EpRet:   284.8 | EpLen:  398
# [Step   72806] EpRet:  -215.4 | EpLen:  596
# [Step   73806] EpRet:   -56.8 | EpLen: 1000
# [Upd   74000] alpha=0.110 | Lq1=28.309 | Lq2=23.979 | Lpi=-29.655
# [Step   74074] EpRet:   235.7 | EpLen:  268
# [Step   74422] EpRet:  -220.5 | EpLen:  348
# [Step   74546] EpRet:   -52.9 | EpLen:  124
# [Step   75118] EpRet:  -302.1 | EpLen:  572
# [Step   75504] EpRet:   258.1 | EpLen:  386
# [Upd   76000] alpha=0.110 | Lq1=14.618 | Lq2=14.775 | Lpi=-29.208
# [Step   76485] EpRet:  -212.5 | EpLen:  981
# [Step   76784] EpRet:   257.9 | EpLen:  299
# [Step   77030] EpRet:   280.2 | EpLen:  246
# [Step   77242] EpRet:   227.4 | EpLen:  212
# [Step   77544] EpRet:   229.7 | EpLen:  302
# [Upd   78000] alpha=0.104 | Lq1=13.576 | Lq2=10.554 | Lpi=-32.943
# [Step   78399] EpRet:   233.5 | EpLen:  855
# [Step   78952] EpRet:   236.7 | EpLen:  553
# [Step   79424] EpRet:   247.4 | EpLen:  472
# [Step   79908] EpRet:   270.6 | EpLen:  484
# [Upd   80000] alpha=0.103 | Lq1=23.103 | Lq2=24.023 | Lpi=-33.429
# == Eval @   80000 steps: mean=144.4 ± 137.4
# [Step   80199] EpRet:   239.3 | EpLen:  291
# [Step   80317] EpRet:    -6.8 | EpLen:  118
# [Step   80556] EpRet:   274.3 | EpLen:  239
# [Step   80671] EpRet:    10.3 | EpLen:  115
# [Step   80940] EpRet:   283.6 | EpLen:  269
# [Step   81020] EpRet:    -5.8 | EpLen:   80
# [Upd   82000] alpha=0.109 | Lq1=8.432 | Lq2=7.983 | Lpi=-31.154
# [Step   82020] EpRet:    80.4 | EpLen: 1000
# [Step   82560] EpRet:  -448.1 | EpLen:  540
# [Step   82642] EpRet:   -43.3 | EpLen:   82
# [Step   83529] EpRet:  -269.8 | EpLen:  887
# [Step   83826] EpRet:   287.1 | EpLen:  297
# [Upd   84000] alpha=0.103 | Lq1=6.589 | Lq2=7.322 | Lpi=-30.822
# [Step   84113] EpRet:  -160.8 | EpLen:  287
# [Step   84387] EpRet:   222.8 | EpLen:  274
# [Step   84736] EpRet:   273.8 | EpLen:  349
# [Step   84930] EpRet:   254.3 | EpLen:  194
# [Step   85198] EpRet:   254.9 | EpLen:  268
# [Upd   86000] alpha=0.105 | Lq1=10.166 | Lq2=9.608 | Lpi=-34.737
# [Step   86198] EpRet:   -37.5 | EpLen: 1000
# [Step   86471] EpRet:   297.3 | EpLen:  273
# [Step   86724] EpRet:   290.2 | EpLen:  253
# [Step   87041] EpRet:   235.2 | EpLen:  317
# [Step   87176] EpRet:    -2.8 | EpLen:  135
# [Step   87938] EpRet:   256.9 | EpLen:  762
# [Upd   88000] alpha=0.115 | Lq1=6.932 | Lq2=6.919 | Lpi=-34.601
# [Step   88146] EpRet:   272.6 | EpLen:  208
# [Step   88374] EpRet:   218.2 | EpLen:  228
# [Step   88761] EpRet:   275.5 | EpLen:  387
# [Step   89097] EpRet:   273.3 | EpLen:  336
# [Step   89327] EpRet:   257.2 | EpLen:  230
# [Step   89903] EpRet:   191.3 | EpLen:  576
# [Upd   90000] alpha=0.121 | Lq1=12.600 | Lq2=14.188 | Lpi=-33.091
# == Eval @   90000 steps: mean=277.2 ± 9.6
# [Step   90079] EpRet:   268.7 | EpLen:  176
# [Step   90362] EpRet:   259.9 | EpLen:  283
# [Step   90605] EpRet:   284.5 | EpLen:  243
# [Step   90837] EpRet:   281.9 | EpLen:  232
# [Step   91036] EpRet:   296.4 | EpLen:  199
# [Step   91248] EpRet:   266.1 | EpLen:  212
# [Step   91679] EpRet:   204.0 | EpLen:  431
# [Step   91848] EpRet:   262.7 | EpLen:  169
# [Upd   92000] alpha=0.117 | Lq1=5.410 | Lq2=6.045 | Lpi=-35.592
# [Step   92119] EpRet:   272.2 | EpLen:  271
# [Step   92286] EpRet:   258.8 | EpLen:  167
# [Step   92463] EpRet:   266.8 | EpLen:  177
# [Step   92555] EpRet:    45.6 | EpLen:   92
# [Step   92721] EpRet:   261.1 | EpLen:  166
# [Step   92978] EpRet:   238.5 | EpLen:  257
# [Step   93978] EpRet:     7.1 | EpLen: 1000
# [Upd   94000] alpha=0.122 | Lq1=27.696 | Lq2=30.294 | Lpi=-34.530
# [Step   94197] EpRet:   254.8 | EpLen:  219
# [Step   94362] EpRet:   272.0 | EpLen:  165
# [Step   94540] EpRet:   254.4 | EpLen:  178
# [Step   94788] EpRet:   204.4 | EpLen:  248
# [Step   95017] EpRet:   267.2 | EpLen:  229
# [Step   95308] EpRet:   294.2 | EpLen:  291
# [Step   95557] EpRet:   256.4 | EpLen:  249
# [Step   95817] EpRet:   290.3 | EpLen:  260
# [Upd   96000] alpha=0.122 | Lq1=14.746 | Lq2=16.446 | Lpi=-36.216
# [Step   96069] EpRet:   273.2 | EpLen:  252
# [Step   96343] EpRet:   271.3 | EpLen:  274
# [Step   96534] EpRet:   273.3 | EpLen:  191
# [Step   96807] EpRet:   223.0 | EpLen:  273
# [Step   97049] EpRet:   231.8 | EpLen:  242
# [Step   97280] EpRet:   218.3 | EpLen:  231
# [Step   97400] EpRet:     0.1 | EpLen:  120
# [Step   97699] EpRet:   272.6 | EpLen:  299
# [Step   97966] EpRet:   228.7 | EpLen:  267
# [Upd   98000] alpha=0.128 | Lq1=18.555 | Lq2=18.030 | Lpi=-34.550
# [Step   98219] EpRet:   247.1 | EpLen:  253
# [Step   98614] EpRet:   258.3 | EpLen:  395
# [Step   99094] EpRet:   236.7 | EpLen:  480
# [Step   99361] EpRet:   279.8 | EpLen:  267
# [Step   99629] EpRet:   281.3 | EpLen:  268
# [Step   99990] EpRet:   262.7 | EpLen:  361
# [Upd  100000] alpha=0.123 | Lq1=12.093 | Lq2=8.745 | Lpi=-34.434
# == Eval @  100000 steps: mean=266.2 ± 22.3
# [Step  100253] EpRet:   296.2 | EpLen:  263
# [Step  100519] EpRet:   280.7 | EpLen:  266
# [Step  100766] EpRet:   209.5 | EpLen:  247
# [Step  101074] EpRet:   304.5 | EpLen:  308
# [Step  101414] EpRet:   225.7 | EpLen:  340
# [Step  101667] EpRet:   289.1 | EpLen:  253
# [Upd  102000] alpha=0.122 | Lq1=6.527 | Lq2=8.066 | Lpi=-37.547
# [Step  102040] EpRet:   222.9 | EpLen:  373
# [Step  102308] EpRet:   231.6 | EpLen:  268
# [Step  102574] EpRet:   263.3 | EpLen:  266
# [Step  103364] EpRet:   234.8 | EpLen:  790
# [Step  103592] EpRet:   261.5 | EpLen:  228
# [Step  103850] EpRet:   265.2 | EpLen:  258
# [Upd  104000] alpha=0.120 | Lq1=12.870 | Lq2=13.221 | Lpi=-41.649
# [Step  104130] EpRet:   273.9 | EpLen:  280
# [Step  104344] EpRet:   236.5 | EpLen:  214
# [Step  104525] EpRet:     2.3 | EpLen:  181
# [Step  104786] EpRet:   263.5 | EpLen:  261
# [Step  104883] EpRet:   -13.9 | EpLen:   97
# [Step  105143] EpRet:   255.6 | EpLen:  260
# [Step  105382] EpRet:   281.8 | EpLen:  239
# [Step  105839] EpRet:   232.0 | EpLen:  457
# [Upd  106000] alpha=0.122 | Lq1=11.578 | Lq2=10.771 | Lpi=-37.235
# [Step  106118] EpRet:   253.5 | EpLen:  279
# [Step  106469] EpRet:   267.9 | EpLen:  351
# [Step  107469] EpRet:    52.3 | EpLen: 1000
# [Step  107842] EpRet:   224.4 | EpLen:  373
# [Upd  108000] alpha=0.113 | Lq1=14.813 | Lq2=16.199 | Lpi=-38.880
# [Step  108111] EpRet:   230.0 | EpLen:  269
# [Step  108297] EpRet:   300.1 | EpLen:  186
# [Step  108528] EpRet:   270.0 | EpLen:  231
# [Step  108816] EpRet:   245.3 | EpLen:  288
# [Step  109194] EpRet:   231.1 | EpLen:  378
# [Step  109459] EpRet:   250.5 | EpLen:  265
# [Step  109717] EpRet:   217.8 | EpLen:  258
# [Upd  110000] alpha=0.113 | Lq1=6.861 | Lq2=8.323 | Lpi=-35.832
# == Eval @  110000 steps: mean=202.6 ± 18.8
# [Step  110012] EpRet:   267.3 | EpLen:  295
# [Step  110443] EpRet:   191.1 | EpLen:  431
# [Step  110880] EpRet:   148.2 | EpLen:  437
# [Step  111211] EpRet:   294.4 | EpLen:  331
# [Step  111411] EpRet:   272.8 | EpLen:  200
# [Step  111693] EpRet:   261.4 | EpLen:  282
# [Upd  112000] alpha=0.111 | Lq1=8.121 | Lq2=8.424 | Lpi=-41.968
# [Step  112010] EpRet:   283.1 | EpLen:  317
# [Step  112279] EpRet:   216.5 | EpLen:  269
# [Step  112554] EpRet:   251.5 | EpLen:  275
# [Step  113027] EpRet:   173.5 | EpLen:  473
# [Step  113346] EpRet:   288.2 | EpLen:  319
# [Step  113696] EpRet:   215.0 | EpLen:  350
# [Upd  114000] alpha=0.108 | Lq1=8.481 | Lq2=8.987 | Lpi=-40.271
# [Step  114002] EpRet:   262.1 | EpLen:  306
# [Step  114305] EpRet:   278.9 | EpLen:  303
# [Step  114599] EpRet:   234.8 | EpLen:  294
# [Step  115141] EpRet:   243.9 | EpLen:  542
# [Step  115459] EpRet:   255.3 | EpLen:  318
# [Step  115793] EpRet:   231.7 | EpLen:  334
# [Upd  116000] alpha=0.110 | Lq1=21.986 | Lq2=19.799 | Lpi=-39.724
# [Step  116092] EpRet:   269.9 | EpLen:  299
# [Step  116372] EpRet:   276.2 | EpLen:  280
# [Step  116576] EpRet:   236.1 | EpLen:  204
# [Step  116816] EpRet:   219.8 | EpLen:  240
# [Step  117027] EpRet:   234.2 | EpLen:  211
# [Step  117302] EpRet:   280.6 | EpLen:  275
# [Step  117491] EpRet:   256.9 | EpLen:  189
# [Upd  118000] alpha=0.109 | Lq1=14.748 | Lq2=12.608 | Lpi=-43.389
# [Step  118012] EpRet:   230.3 | EpLen:  521
# [Step  118220] EpRet:   253.7 | EpLen:  208
# [Step  118427] EpRet:   256.4 | EpLen:  207
# [Step  118596] EpRet:   236.3 | EpLen:  169
# [Step  118886] EpRet:   282.1 | EpLen:  290
# [Step  119101] EpRet:   197.2 | EpLen:  215
# [Step  119351] EpRet:   264.1 | EpLen:  250
# [Step  119540] EpRet:   249.2 | EpLen:  189
# [Upd  120000] alpha=0.104 | Lq1=5.689 | Lq2=6.490 | Lpi=-43.381
# == Eval @  120000 steps: mean=266.3 ± 12.7
# [Step  120056] EpRet:   132.0 | EpLen:  516
# [Step  120231] EpRet:   267.3 | EpLen:  175
# [Step  120453] EpRet:   248.2 | EpLen:  222
# [Step  120738] EpRet:   296.7 | EpLen:  285
# [Step  120910] EpRet:   260.3 | EpLen:  172
# [Step  121149] EpRet:   288.5 | EpLen:  239
# [Step  121220] EpRet:    31.6 | EpLen:   71
# [Step  121486] EpRet:   257.1 | EpLen:  266
# [Step  121650] EpRet:   256.4 | EpLen:  164
# [Step  121845] EpRet:   259.6 | EpLen:  195
# [Step  121932] EpRet:    31.6 | EpLen:   87
# [Upd  122000] alpha=0.107 | Lq1=8.316 | Lq2=8.366 | Lpi=-42.569
# [Step  122106] EpRet:   288.4 | EpLen:  174
# [Step  122403] EpRet:   270.2 | EpLen:  297
# [Step  122532] EpRet:    46.9 | EpLen:  129
# [Step  122829] EpRet:   282.8 | EpLen:  297
# [Step  122954] EpRet:    10.7 | EpLen:  125
# [Step  123163] EpRet:   256.8 | EpLen:  209
# [Step  123256] EpRet:    11.5 | EpLen:   93
# [Step  123566] EpRet:   222.2 | EpLen:  310
# [Step  123643] EpRet:   -66.7 | EpLen:   77
# [Step  123748] EpRet:     6.1 | EpLen:  105
# [Step  123821] EpRet:    29.8 | EpLen:   73
# [Step  123904] EpRet:    -5.4 | EpLen:   83
# [Upd  124000] alpha=0.102 | Lq1=14.038 | Lq2=13.124 | Lpi=-44.295
# [Step  124126] EpRet:    24.7 | EpLen:  222
# [Step  124219] EpRet:   -32.1 | EpLen:   93
# [Step  124439] EpRet:   -55.5 | EpLen:  220
# [Step  124501] EpRet:   -36.6 | EpLen:   62
# [Step  124767] EpRet:   282.0 | EpLen:  266
# [Step  125037] EpRet:   269.0 | EpLen:  270
# [Step  125217] EpRet:   296.5 | EpLen:  180
# [Step  125313] EpRet:    -4.5 | EpLen:   96
# [Step  125612] EpRet:   276.6 | EpLen:  299
# [Step  125836] EpRet:   276.7 | EpLen:  224
# [Upd  126000] alpha=0.102 | Lq1=15.104 | Lq2=14.931 | Lpi=-46.136
# [Step  126018] EpRet:   246.5 | EpLen:  182
# [Step  126135] EpRet:   -12.6 | EpLen:  117
# [Step  126294] EpRet:   253.2 | EpLen:  159
# [Step  126575] EpRet:   275.9 | EpLen:  281
# [Step  126645] EpRet:   -87.1 | EpLen:   70
# [Step  126858] EpRet:   244.6 | EpLen:  213
# [Step  127145] EpRet:   293.8 | EpLen:  287
# [Step  127411] EpRet:   260.9 | EpLen:  266
# [Step  127506] EpRet:    -9.4 | EpLen:   95
# [Step  127611] EpRet:    10.9 | EpLen:  105
# [Upd  128000] alpha=0.098 | Lq1=6.425 | Lq2=10.385 | Lpi=-42.076
# [Step  128611] EpRet:     8.9 | EpLen: 1000
# [Step  128699] EpRet:     4.0 | EpLen:   88
# [Step  128886] EpRet:   284.3 | EpLen:  187
# [Step  129043] EpRet:   221.0 | EpLen:  157
# [Step  129291] EpRet:   257.1 | EpLen:  248
# [Step  129556] EpRet:   280.4 | EpLen:  265
# [Step  129761] EpRet:   260.4 | EpLen:  205
# [Step  129973] EpRet:   238.5 | EpLen:  212
# [Upd  130000] alpha=0.093 | Lq1=9.026 | Lq2=9.111 | Lpi=-44.541
# == Eval @  130000 steps: mean=159.5 ± 126.1
# [Step  130239] EpRet:   263.6 | EpLen:  266
# [Step  130438] EpRet:   206.5 | EpLen:  199
# [Step  130640] EpRet:   248.9 | EpLen:  202
# [Step  130889] EpRet:   263.2 | EpLen:  249
# [Step  131160] EpRet:   270.8 | EpLen:  271
# [Step  131352] EpRet:   287.6 | EpLen:  192
# [Step  131524] EpRet:   240.0 | EpLen:  172
# [Step  131813] EpRet:   277.6 | EpLen:  289
# [Upd  132000] alpha=0.094 | Lq1=5.303 | Lq2=4.477 | Lpi=-44.603
# [Step  132136] EpRet:   287.3 | EpLen:  323
# [Step  132340] EpRet:   235.9 | EpLen:  204
# [Step  132616] EpRet:   281.4 | EpLen:  276
# [Step  132710] EpRet:   -35.3 | EpLen:   94
# [Step  132794] EpRet:   -13.3 | EpLen:   84
# [Step  132973] EpRet:   271.3 | EpLen:  179
# [Step  133238] EpRet:   268.9 | EpLen:  265
# [Step  133458] EpRet:   274.8 | EpLen:  220
# [Step  133744] EpRet:  -223.7 | EpLen:  286
# [Step  133973] EpRet:   251.5 | EpLen:  229
# [Upd  134000] alpha=0.093 | Lq1=8.662 | Lq2=10.094 | Lpi=-47.543
# [Step  134268] EpRet:   259.2 | EpLen:  295
# [Step  134544] EpRet:   253.4 | EpLen:  276
# [Step  134752] EpRet:   289.0 | EpLen:  208
# [Step  134949] EpRet:   232.4 | EpLen:  197
# [Step  135163] EpRet:   251.4 | EpLen:  214
# [Step  135456] EpRet:   279.2 | EpLen:  293
# [Step  135690] EpRet:   274.2 | EpLen:  234
# [Step  135922] EpRet:   258.0 | EpLen:  232
# [Upd  136000] alpha=0.090 | Lq1=11.117 | Lq2=15.326 | Lpi=-45.976
# [Step  136098] EpRet:   290.8 | EpLen:  176
# [Step  136501] EpRet:   255.6 | EpLen:  403
# [Step  136782] EpRet:   277.2 | EpLen:  281
# [Step  137051] EpRet:   286.8 | EpLen:  269
# [Step  137241] EpRet:   256.2 | EpLen:  190
# [Step  137471] EpRet:   273.1 | EpLen:  230
# [Step  137791] EpRet:   260.7 | EpLen:  320
# [Step  137955] EpRet:  -264.1 | EpLen:  164
# [Upd  138000] alpha=0.090 | Lq1=11.376 | Lq2=7.944 | Lpi=-43.909
# [Step  138169] EpRet:   287.3 | EpLen:  214
# [Step  138365] EpRet:   236.2 | EpLen:  196
# [Step  138643] EpRet:   251.0 | EpLen:  278
# [Step  138881] EpRet:   289.4 | EpLen:  238
# [Step  139297] EpRet:   292.6 | EpLen:  416
# [Step  139587] EpRet:   260.1 | EpLen:  290
# [Step  139775] EpRet:   246.4 | EpLen:  188
# [Step  139985] EpRet:   226.7 | EpLen:  210
# [Upd  140000] alpha=0.095 | Lq1=27.412 | Lq2=27.081 | Lpi=-43.600
# == Eval @  140000 steps: mean=273.4 ± 10.7
# [Step  140472] EpRet:   243.1 | EpLen:  487
# [Step  140759] EpRet:   264.9 | EpLen:  287
# [Step  140984] EpRet:   260.9 | EpLen:  225
# [Step  141164] EpRet:   248.8 | EpLen:  180
# [Step  141494] EpRet:   249.8 | EpLen:  330
# [Step  141717] EpRet:   259.7 | EpLen:  223
# [Step  141967] EpRet:   243.8 | EpLen:  250
# [Upd  142000] alpha=0.099 | Lq1=25.358 | Lq2=30.113 | Lpi=-44.802
# [Step  142967] EpRet:   -24.4 | EpLen: 1000
# [Step  143243] EpRet:   287.5 | EpLen:  276
# [Step  143485] EpRet:   263.0 | EpLen:  242
# [Step  143784] EpRet:   293.0 | EpLen:  299
# [Upd  144000] alpha=0.096 | Lq1=7.076 | Lq2=7.211 | Lpi=-48.413
# [Step  144038] EpRet:   266.9 | EpLen:  254
# [Step  144236] EpRet:   275.1 | EpLen:  198
# [Step  144574] EpRet:   280.5 | EpLen:  338
# [Step  144824] EpRet:   262.8 | EpLen:  250
# [Step  145018] EpRet:   261.7 | EpLen:  194
# [Step  145241] EpRet:   284.9 | EpLen:  223
# [Step  145448] EpRet:   267.3 | EpLen:  207
# [Step  145844] EpRet:   279.9 | EpLen:  396
# [Upd  146000] alpha=0.095 | Lq1=17.203 | Lq2=15.644 | Lpi=-44.556
# [Step  146073] EpRet:   262.3 | EpLen:  229
# [Step  146340] EpRet:   269.7 | EpLen:  267
# [Step  146568] EpRet:   277.3 | EpLen:  228
# [Step  146798] EpRet:   239.3 | EpLen:  230
# [Step  146998] EpRet:   281.9 | EpLen:  200
# [Step  147206] EpRet:   275.9 | EpLen:  208
# [Step  147375] EpRet:   253.2 | EpLen:  169
# [Step  147577] EpRet:   247.8 | EpLen:  202
# [Step  147780] EpRet:   236.2 | EpLen:  203
# [Step  147970] EpRet:   240.2 | EpLen:  190
# [Upd  148000] alpha=0.098 | Lq1=9.930 | Lq2=10.336 | Lpi=-51.237
# [Step  148277] EpRet:   276.1 | EpLen:  307
# [Step  148701] EpRet:   290.9 | EpLen:  424
# [Step  148880] EpRet:   250.1 | EpLen:  179
# [Step  149085] EpRet:   247.9 | EpLen:  205
# [Step  149270] EpRet:   243.0 | EpLen:  185
# [Step  149507] EpRet:   292.3 | EpLen:  237
# [Step  149710] EpRet:   267.9 | EpLen:  203
# [Step  149994] EpRet:   277.6 | EpLen:  284
# [Upd  150000] alpha=0.101 | Lq1=9.494 | Lq2=10.286 | Lpi=-51.028
# == Eval @  150000 steps: mean=266.5 ± 15.0
# [Step  150263] EpRet:   274.4 | EpLen:  269
# [Step  150817] EpRet:   279.4 | EpLen:  554
# [Step  150994] EpRet:   269.0 | EpLen:  177
# [Step  151231] EpRet:   272.0 | EpLen:  237
# [Step  151851] EpRet:   268.5 | EpLen:  620
# [Upd  152000] alpha=0.095 | Lq1=14.641 | Lq2=13.920 | Lpi=-49.462
# [Step  152258] EpRet:   203.7 | EpLen:  407
# [Step  152471] EpRet:   258.7 | EpLen:  213
# [Step  153340] EpRet:   269.7 | EpLen:  869
# [Step  153580] EpRet:   288.0 | EpLen:  240
# [Step  153841] EpRet:   301.8 | EpLen:  261
# [Upd  154000] alpha=0.090 | Lq1=4.790 | Lq2=4.211 | Lpi=-48.355
# [Step  154682] EpRet:   260.5 | EpLen:  841
# [Step  154897] EpRet:   267.7 | EpLen:  215
# [Step  155158] EpRet:   286.4 | EpLen:  261
# [Step  155393] EpRet:   224.1 | EpLen:  235
# [Step  155589] EpRet:   244.8 | EpLen:  196
# [Step  155802] EpRet:   282.6 | EpLen:  213
# [Upd  156000] alpha=0.090 | Lq1=7.983 | Lq2=8.735 | Lpi=-50.265
# [Step  156006] EpRet:   303.7 | EpLen:  204
# [Step  156740] EpRet:   237.4 | EpLen:  734
# [Step  157740] EpRet:    76.0 | EpLen: 1000
# [Step  157975] EpRet:   282.8 | EpLen:  235
# [Upd  158000] alpha=0.093 | Lq1=10.057 | Lq2=8.564 | Lpi=-49.641
# [Step  158512] EpRet:   228.5 | EpLen:  537
# [Step  158679] EpRet:   219.7 | EpLen:  167
# [Step  158926] EpRet:   264.0 | EpLen:  247
# [Step  159323] EpRet:   294.8 | EpLen:  397
# [Step  159587] EpRet:   256.7 | EpLen:  264
# [Step  159824] EpRet:   269.6 | EpLen:  237
# [Upd  160000] alpha=0.089 | Lq1=15.119 | Lq2=14.470 | Lpi=-52.210
# == Eval @  160000 steps: mean=260.3 ± 21.3
# [Step  160083] EpRet:   264.7 | EpLen:  259
# [Step  160392] EpRet:   236.7 | EpLen:  309
# [Step  160591] EpRet:   255.3 | EpLen:  199
# [Step  160824] EpRet:   289.0 | EpLen:  233
# [Step  161090] EpRet:   234.6 | EpLen:  266
# [Step  161450] EpRet:   254.4 | EpLen:  360
# [Step  161786] EpRet:   248.7 | EpLen:  336
# [Upd  162000] alpha=0.093 | Lq1=10.391 | Lq2=12.110 | Lpi=-47.820
# [Step  162152] EpRet:   227.6 | EpLen:  366
# [Step  162411] EpRet:   286.2 | EpLen:  259
# [Step  162646] EpRet:   297.8 | EpLen:  235
# [Step  162835] EpRet:   243.4 | EpLen:  189
# [Step  163835] EpRet:    29.0 | EpLen: 1000
# [Upd  164000] alpha=0.094 | Lq1=6.722 | Lq2=5.956 | Lpi=-53.430
# [Step  164260] EpRet:   210.9 | EpLen:  425
# [Step  165158] EpRet:  -364.8 | EpLen:  898
# [Step  165482] EpRet:   204.2 | EpLen:  324
# [Upd  166000] alpha=0.091 | Lq1=4.611 | Lq2=4.869 | Lpi=-53.369
# [Step  166375] EpRet:   202.5 | EpLen:  893
# [Step  166561] EpRet:   267.3 | EpLen:  186
# [Step  166822] EpRet:   224.8 | EpLen:  261
# [Step  167033] EpRet:   246.6 | EpLen:  211
# [Step  167293] EpRet:   247.8 | EpLen:  260
# [Step  167508] EpRet:   275.4 | EpLen:  215
# [Step  167744] EpRet:   257.4 | EpLen:  236
# [Upd  168000] alpha=0.092 | Lq1=11.740 | Lq2=8.085 | Lpi=-51.350
# [Step  168023] EpRet:   234.1 | EpLen:  279
# [Step  168263] EpRet:   291.4 | EpLen:  240
# [Step  168522] EpRet:   286.3 | EpLen:  259
# [Step  169016] EpRet:   239.4 | EpLen:  494
# [Step  169295] EpRet:   292.8 | EpLen:  279
# [Step  169481] EpRet:   268.3 | EpLen:  186
# [Step  169969] EpRet:   224.0 | EpLen:  488
# [Upd  170000] alpha=0.091 | Lq1=9.484 | Lq2=9.545 | Lpi=-54.523
# == Eval @  170000 steps: mean=140.3 ± 142.4
# [Step  170551] EpRet:   234.2 | EpLen:  582
# [Step  171147] EpRet:   191.8 | EpLen:  596
# [Step  171355] EpRet:   249.7 | EpLen:  208
# [Step  171890] EpRet:   248.1 | EpLen:  535
# [Upd  172000] alpha=0.086 | Lq1=37.328 | Lq2=30.049 | Lpi=-52.398
# [Step  172092] EpRet:   273.3 | EpLen:  202
# [Step  172349] EpRet:   234.4 | EpLen:  257
# [Step  172572] EpRet:   257.1 | EpLen:  223
# [Step  173424] EpRet:  -122.5 | EpLen:  852
# [Step  173613] EpRet:   262.8 | EpLen:  189
# [Step  173804] EpRet:   242.4 | EpLen:  191
# [Upd  174000] alpha=0.084 | Lq1=6.566 | Lq2=7.814 | Lpi=-53.790
# [Step  174051] EpRet:   262.4 | EpLen:  247
# [Step  174280] EpRet:   300.3 | EpLen:  229
# [Step  174542] EpRet:   242.1 | EpLen:  262
# [Step  174848] EpRet:   265.6 | EpLen:  306
# [Step  175086] EpRet:   283.4 | EpLen:  238
# [Step  175340] EpRet:   307.3 | EpLen:  254
# [Step  175624] EpRet:   242.5 | EpLen:  284
# [Step  175854] EpRet:   248.0 | EpLen:  230
# [Upd  176000] alpha=0.089 | Lq1=85.116 | Lq2=80.540 | Lpi=-53.511
# [Step  176090] EpRet:   258.4 | EpLen:  236
# [Step  176303] EpRet:   268.6 | EpLen:  213
# [Step  176474] EpRet:   253.2 | EpLen:  171
# [Step  176765] EpRet:   -16.4 | EpLen:  291
# [Step  177028] EpRet:   217.0 | EpLen:  263
# [Step  177285] EpRet:   287.8 | EpLen:  257
# [Step  177680] EpRet:   228.6 | EpLen:  395
# [Step  177891] EpRet:   212.0 | EpLen:  211
# [Upd  178000] alpha=0.085 | Lq1=11.617 | Lq2=12.141 | Lpi=-56.042
# [Step  178891] EpRet:    93.1 | EpLen: 1000
# [Step  179166] EpRet:   304.0 | EpLen:  275
# [Step  179364] EpRet:   241.7 | EpLen:  198
# [Step  179610] EpRet:   275.8 | EpLen:  246
# [Step  179820] EpRet:   240.1 | EpLen:  210
# [Upd  180000] alpha=0.084 | Lq1=36.795 | Lq2=20.867 | Lpi=-52.050
# == Eval @  180000 steps: mean=190.0 ± 156.0
# [Step  180048] EpRet:   274.6 | EpLen:  228
# [Step  181048] EpRet:    40.1 | EpLen: 1000
# [Step  181244] EpRet:   254.5 | EpLen:  196
# [Step  181468] EpRet:   256.3 | EpLen:  224
# [Step  181847] EpRet:   207.8 | EpLen:  379
# [Upd  182000] alpha=0.083 | Lq1=7.350 | Lq2=7.921 | Lpi=-56.408
# [Step  182080] EpRet:   269.9 | EpLen:  233
# [Step  182243] EpRet:   278.9 | EpLen:  163
# [Step  182487] EpRet:   263.3 | EpLen:  244
# [Step  182816] EpRet:   306.4 | EpLen:  329
# [Step  183367] EpRet:   227.6 | EpLen:  551
# [Step  183560] EpRet:   225.3 | EpLen:  193
# [Step  183794] EpRet:   302.6 | EpLen:  234
# [Upd  184000] alpha=0.084 | Lq1=36.591 | Lq2=30.363 | Lpi=-48.936
# [Step  184453] EpRet:   242.2 | EpLen:  659
# [Step  184612] EpRet:   266.2 | EpLen:  159
# [Step  184952] EpRet:   241.7 | EpLen:  340
# [Step  185190] EpRet:   286.8 | EpLen:  238
# [Step  185436] EpRet:   277.8 | EpLen:  246
# [Upd  186000] alpha=0.078 | Lq1=20.351 | Lq2=22.665 | Lpi=-52.806
# [Step  186103] EpRet:   263.4 | EpLen:  667
# [Step  186298] EpRet:   248.2 | EpLen:  195
# [Step  186614] EpRet:   231.4 | EpLen:  316
# [Step  186780] EpRet:   241.3 | EpLen:  166
# [Step  187045] EpRet:   279.2 | EpLen:  265
# [Step  187266] EpRet:   266.5 | EpLen:  221
# [Step  187447] EpRet:   253.7 | EpLen:  181
# [Step  187638] EpRet:   259.6 | EpLen:  191
# [Step  187850] EpRet:   264.5 | EpLen:  212
# [Upd  188000] alpha=0.082 | Lq1=5.919 | Lq2=7.493 | Lpi=-52.610
# [Step  188179] EpRet:   275.2 | EpLen:  329
# [Step  188429] EpRet:   286.6 | EpLen:  250
# [Step  188658] EpRet:   234.3 | EpLen:  229
# [Step  188909] EpRet:   250.8 | EpLen:  251
# [Step  189259] EpRet:   272.0 | EpLen:  350
# [Step  189482] EpRet:   190.8 | EpLen:  223
# [Step  189712] EpRet:   255.0 | EpLen:  230
# [Step  189856] EpRet:   256.9 | EpLen:  144
# [Upd  190000] alpha=0.081 | Lq1=4.351 | Lq2=4.204 | Lpi=-57.023
# == Eval @  190000 steps: mean=256.4 ± 13.7
# [Step  190128] EpRet:   271.2 | EpLen:  272
# [Step  190381] EpRet:   274.0 | EpLen:  253
# [Step  190630] EpRet:   258.9 | EpLen:  249
# [Step  190848] EpRet:   274.7 | EpLen:  218
# [Step  191228] EpRet:   270.3 | EpLen:  380
# [Step  191545] EpRet:   280.9 | EpLen:  317
# [Step  191736] EpRet:   243.9 | EpLen:  191
# [Step  191984] EpRet:   278.1 | EpLen:  248
# [Upd  192000] alpha=0.081 | Lq1=8.692 | Lq2=12.598 | Lpi=-52.771
# [Step  192237] EpRet:   251.6 | EpLen:  253
# [Step  192485] EpRet:   235.9 | EpLen:  248
# [Step  192746] EpRet:   300.4 | EpLen:  261
# [Step  192912] EpRet:   238.7 | EpLen:  166
# [Step  193158] EpRet:   290.2 | EpLen:  246
# [Step  193377] EpRet:   229.4 | EpLen:  219
# [Step  193556] EpRet:   245.4 | EpLen:  179
# [Step  193783] EpRet:   260.9 | EpLen:  227
# [Upd  194000] alpha=0.082 | Lq1=22.735 | Lq2=24.265 | Lpi=-56.758
# [Step  194050] EpRet:   255.5 | EpLen:  267
# [Step  194337] EpRet:   280.4 | EpLen:  287
# [Step  194622] EpRet:   272.8 | EpLen:  285
# [Step  194773] EpRet:   282.9 | EpLen:  151
# [Step  195050] EpRet:   256.6 | EpLen:  277
# [Step  195341] EpRet:   305.5 | EpLen:  291
# [Step  195639] EpRet:   282.2 | EpLen:  298
# [Step  195912] EpRet:   292.2 | EpLen:  273
# [Upd  196000] alpha=0.081 | Lq1=26.003 | Lq2=25.272 | Lpi=-56.786
# [Step  196126] EpRet:   247.2 | EpLen:  214
# [Step  196292] EpRet:   241.9 | EpLen:  166
# [Step  196566] EpRet:   286.3 | EpLen:  274
# [Step  196720] EpRet:   276.0 | EpLen:  154
# [Step  196919] EpRet:   263.8 | EpLen:  199
# [Step  197266] EpRet:   285.2 | EpLen:  347
# [Step  197574] EpRet:   282.0 | EpLen:  308
# [Step  197838] EpRet:   281.9 | EpLen:  264
# [Upd  198000] alpha=0.081 | Lq1=18.408 | Lq2=20.154 | Lpi=-54.448
# [Step  198104] EpRet:   291.7 | EpLen:  266
# [Step  198400] EpRet:   285.7 | EpLen:  296
# [Step  198598] EpRet:   262.2 | EpLen:  198
# [Step  198848] EpRet:   284.4 | EpLen:  250
# [Step  199105] EpRet:   245.3 | EpLen:  257
# [Step  199324] EpRet:   243.9 | EpLen:  219
# [Step  199526] EpRet:   246.0 | EpLen:  202
# [Step  199860] EpRet:   263.4 | EpLen:  334
# [Upd  200000] alpha=0.079 | Lq1=7.844 | Lq2=8.774 | Lpi=-59.318
# == Eval @  200000 steps: mean=268.1 ± 19.2
# Training done. Recording deterministic demo...
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:296: UserWarning: WARN: Overwriting existing videos at /content/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Saved video(s) to: /content/videos
